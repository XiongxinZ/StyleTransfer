# %% [markdown]
# Notebook from github repo: https://github.com/titu1994/Neural-Style-Transfer

# %% [markdown]
# If you are running in colab, select tensorflow version 1.x:

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Or, if running locally, you need tensorflow version below 2

# %%
#!pip install -q 'tensorflow-gpu<2'

# %%
# !pip install -q 'scipy<=1.2.1'  # scipy.misc.imread is deprecated in later versions

# %%
# !git clone https://github.com/titu1994/Neural-Style-Transfer.git
# Out:
# Cloning into 'Neural-Style-Transfer'...
# remote: Enumerating objects: 1400, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 1400 (delta 1), reused 3 (delta 0), pack-reused 1393
# Receiving objects: 100% (1400/1400), 68.16 MiB | 25.64 MiB/s, done.
# Resolving deltas: 100% (820/820), done.

# %%
dir_path = "Neural-Style-Transfer"

# %% [markdown]
# # Network Type
#
# Choose the network type below :
#
# - "Network" for the original style transfer
# - "INetwork" for the improved style transfer (default)

# %%
NETWORK = 'INetwork' + '.py'

# %%
# List all the arguments that can be supplied to Network.py
# !python {dir_path}/{NETWORK} -h
# Out:
# /usr/local/lib/python3.6/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# usage: INetwork.py [-h] [--style_masks STYLE_MASKS [STYLE_MASKS ...]]
#                    [--content_mask CONTENT_MASK] [--color_mask COLOR_MASK]
#                    [--image_size IMG_SIZE] [--content_weight CONTENT_WEIGHT]
#                    [--style_weight STYLE_WEIGHT [STYLE_WEIGHT ...]]
#                    [--style_scale STYLE_SCALE]
#                    [--total_variation_weight TV_WEIGHT] [--num_iter NUM_ITER]
#                    [--model MODEL] [--content_loss_type CONTENT_LOSS_TYPE]
#                    [--rescale_image RESCALE_IMAGE]
#                    [--rescale_method RESCALE_METHOD]
#                    [--maintain_aspect_ratio MAINTAIN_ASPECT_RATIO]
#                    [--content_layer CONTENT_LAYER] [--init_image INIT_IMAGE]
#                    [--pool_type POOL] [--preserve_color COLOR]
#                    [--min_improvement MIN_IMPROVEMENT]
#                    base ref [ref ...] res_prefix
#
# Neural style transfer with Keras.
#
# positional arguments:
#   base                  Path to the image to transform.
#   ref                   Path to the style reference image.
#   res_prefix            Prefix for the saved results.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --style_masks STYLE_MASKS [STYLE_MASKS ...]
#                         Masks for style images
#   --content_mask CONTENT_MASK
#                         Masks for the content image
#   --color_mask COLOR_MASK
#                         Mask for color preservation
#   --image_size IMG_SIZE
#                         Minimum image size
#   --content_weight CONTENT_WEIGHT
#                         Weight of content
#   --style_weight STYLE_WEIGHT [STYLE_WEIGHT ...]
#                         Weight of style, can be multiple for multiple styles
#   --style_scale STYLE_SCALE
#                         Scale the weighing of the style
#   --total_variation_weight TV_WEIGHT
#                         Total Variation weight
#   --num_iter NUM_ITER   Number of iterations
#   --model MODEL         Choices are 'vgg16' and 'vgg19'
#   --content_loss_type CONTENT_LOSS_TYPE
#                         Can be one of 0, 1 or 2. Readme contains the required
#                         information of each mode.
#   --rescale_image RESCALE_IMAGE
#                         Rescale image after execution to original dimentions
#   --rescale_method RESCALE_METHOD
#                         Rescale image algorithm
#   --maintain_aspect_ratio MAINTAIN_ASPECT_RATIO
#                         Maintain aspect ratio of loaded images
#   --content_layer CONTENT_LAYER
#                         Content layer used for content loss.
#   --init_image INIT_IMAGE
#                         Initial image used to generate the final image.
#                         Options are 'content', 'noise', or 'gray'
#   --pool_type POOL      Pooling type. Can be "ave" for average pooling or
#                         "max" for max pooling
#   --preserve_color COLOR
#                         Preserve original color in image
#   --min_improvement MIN_IMPROVEMENT
#                         Defines minimum improvement required to continue
#                         script

# %% [markdown]
# # Network Parameters
#
# Here, we will setup all of the parameters for the `Network.py` script.

# %%
# Image size
IMAGE_SIZE = 500

# Loss Weights
CONTENT_WEIGHT = 1e-5
STYLE_WEIGHT = 1.0
STYLE_SCALE = 1.0
TOTAL_VARIATION_WEIGHT = 8.5e-5
CONTENT_LOSS_TYPE = 0

# Training arguments
NUM_ITERATIONS = 30
MODEL = 'vgg19'
RESCALE_IMAGE = 'false'
MAINTAIN_ASPECT_RATIO = 'false'  # Set to false if OOM occurs

# Transfer Arguments
CONTENT_LAYER = 'conv' + '5_4'  # only change the number 5_2 to something in a similar format
INITIALIZATION_IMAGE = 'content'
POOLING_TYPE = 'ave'

# Extra arguments
PRESERVE_COLOR = 'false'
MIN_IMPROVEMENT = 0.0

# %% [markdown]
# # Content Image
#
# Run the below cell to upload the Content Image. Make sure to select **just 1 image**

# %%
from google.colab import files

content_img = files.upload()
# Out:
#      <input type="file" id="files-79badcb5-f49f-475f-ad7a-a8a0d115503d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-79badcb5-f49f-475f-ad7a-a8a0d115503d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 000529.jpeg to 000529.jpeg

# %%
import os

CONTENT_IMAGE_FN = list(content_img)[0]
CONTENT_IMAGE_FN_temp = CONTENT_IMAGE_FN.strip().replace(" ", "_")

if CONTENT_IMAGE_FN != CONTENT_IMAGE_FN_temp:
  os.rename(CONTENT_IMAGE_FN, CONTENT_IMAGE_FN_temp)
  CONTENT_IMAGE_FN = CONTENT_IMAGE_FN_temp
  
print("Content image filename :", CONTENT_IMAGE_FN)
# Out:
# Content image filename : 000529.jpeg

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10, 10))
img = plt.imread(CONTENT_IMAGE_FN)
plt.axis('off')
plt.title('Content image')
plt.imshow(img)

# %% [markdown]
# # Style Image
#
# Run the below cell to upload the Style Image. Make sure to select **just 1 image**

# %%
style_img = files.upload()
# Out:
#      <input type="file" id="files-23f9bb1c-7d75-4234-b562-e9650854b8cd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-23f9bb1c-7d75-4234-b562-e9650854b8cd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving style.png to style.png

# %%
STYLE_IMAGE_FN = list(style_img)[0]
STYLE_IMAGE_FN_temp = STYLE_IMAGE_FN.strip().replace(" ", "_")

if STYLE_IMAGE_FN != STYLE_IMAGE_FN_temp:
  os.rename(STYLE_IMAGE_FN, STYLE_IMAGE_FN_temp)
  STYLE_IMAGE_FN = STYLE_IMAGE_FN_temp

print("Style image filename :", STYLE_IMAGE_FN)
# Out:
# Style image filename : style.png

# %%
fig = plt.figure(figsize=(10, 10))
img = plt.imread(STYLE_IMAGE_FN)
plt.axis('off')
plt.title('Style image')
plt.imshow(img)

# %% [markdown]
# # Generate Image
#
# Run the below cells to generate the image

# %%
import os

RESULT_DIR = "/content/gdrive/MyDrive/style_transfer_images/"
RESULT_PREFIX = RESULT_DIR + "side_ab2"
FINAL_IMAGE_PATH = RESULT_PREFIX + "_at_iteration_%d.png" % (NUM_ITERATIONS)

# if not os.path.exists(RESULT_DIR):
#   os.makedirs(RESULT_DIR)

# %%
# !python {dir_path}/{NETWORK} {CONTENT_IMAGE_FN} {STYLE_IMAGE_FN} {RESULT_PREFIX} \
  --image_size {IMAGE_SIZE} --content_weight {CONTENT_WEIGHT} --style_weight \
  {STYLE_WEIGHT} --style_scale {STYLE_SCALE} --total_variation_weight \
  {TOTAL_VARIATION_WEIGHT} --content_loss_type {CONTENT_LOSS_TYPE} --num_iter \
  {NUM_ITERATIONS} --model {MODEL} --rescale_image {RESCALE_IMAGE} \
  --maintain_aspect_ratio {MAINTAIN_ASPECT_RATIO} --content_layer {CONTENT_LAYER} \
  --init_image {INITIALIZATION_IMAGE} --pool_type {POOLING_TYPE} --preserve_color \
  {PRESERVE_COLOR} --min_improvement {MIN_IMPROVEMENT}
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:4074: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# 2021-04-27 17:31:22.532325: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-04-27 17:31:22.562050: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-27 17:31:22.563042: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2021-04-27 17:31:22.564250: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-04-27 17:31:22.566155: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-04-27 17:31:22.567852: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-04-27 17:31:22.568244: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-04-27 17:31:22.570306: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-04-27 17:31:22.571513: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-04-27 17:31:22.576255: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-04-27 17:31:22.576371: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-27 17:31:22.577275: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-27 17:31:22.578046: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2021-04-27 17:31:22.584138: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2299995000 Hz
# 2021-04-27 17:31:22.584426: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55ab630b8fc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-04-27 17:31:22.584465: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-04-27 17:31:22.639920: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-27 17:31:22.640933: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55ab630b9180 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-04-27 17:31:22.640985: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2021-04-27 17:31:22.641177: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-27 17:31:22.641976: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2021-04-27 17:31:22.642058: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-04-27 17:31:22.642106: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-04-27 17:31:22.642149: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-04-27 17:31:22.642194: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-04-27 17:31:22.642232: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-04-27 17:31:22.642270: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-04-27 17:31:22.642309: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-04-27 17:31:22.642399: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-27 17:31:22.643247: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-27 17:31:22.644027: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2021-04-27 17:31:22.644095: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-04-27 17:31:22.645388: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-04-27 17:31:22.645422: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2021-04-27 17:31:22.645446: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2021-04-27 17:31:22.645593: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-27 17:31:22.646369: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-27 17:31:22.647091: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-04-27 17:31:22.647147: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10813 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# Model loaded.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/math_grad.py:1375: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Starting iteration 1 of 30
# 2021-04-27 17:31:28.377678: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-04-27 17:31:28.545077: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# Current loss value: 15689887.0  Improvement : 0.000 %
# Rescaling Image to (500, 408)
# Image saved as /content/gdrive/MyDrive/style_transfer_images/side_ab2_at_iteration_1.png
# Iteration 1 completed in 31s
# Starting iteration 2 of 30
# Current loss value: 5700207.5  Improvement : 63.670 %
# Rescaling Image to (500, 408)
# Image saved as /content/gdrive/MyDrive/style_transfer_images/side_ab2_at_iteration_1.png
# Iteration 2 completed in 24s
# Starting iteration 3 of 30
# Current loss value: 3413662.8  Improvement : 40.113 %
# Rescaling Image to (500, 408)
# Image saved as /content/gdrive/MyDrive/style_transfer_images/side_ab2_at_iteration_1.png
# Iteration 3 completed in 24s
# Starting iteration 4 of 30
# Current loss value: 2543077.8  Improvement : 25.503 %
# Rescaling Image to (500, 408)
# Image saved as /content/gdrive/MyDrive/style_transfer_images/side_ab2_at_iteration_1.png
# Iteration 4 completed in 24s
# Starting iteration 5 of 30
# Current loss value: 2026109.5  Improvement : 20.328 %
# Rescaling Image to (500, 408)
# Image saved as /content/gdrive/MyDrive/style_transfer_images/side_ab2_at_iteration_1.png
# Iteration 5 completed in 24s
# Starting iteration 6 of 30
# Current loss value: 1694385.8  Improvement : 16.372 %
# Rescaling Image to (500, 408)
# Image saved as /content/gdrive/MyDrive/style_transfer_images/side_ab2_at_iteration_6.png
# Iteration 6 completed in 24s
# Starting iteration 7 of 30
# Current loss value: 1507258.0  Improvement : 11.044 %
# Rescaling Image to (500, 408)
# Image saved as /content/gdrive/MyDrive/style_transfer_images/side_ab2_at_iteration_6.png
# Iteration 7 completed in 24s
# Starting iteration 8 of 30
# Current loss value: 1361431.9  Improvement : 9.675 %
# Rescaling Image to (500, 408)
# Image saved as /content/gdrive/MyDrive/style_transfer_images/side_ab2_at_iteration_6.png
# Iteration 8 completed in 24s
# Starting iteration 9 of 30
# Current loss value: 1261728.8  Improvement : 7.323 %
# Rescaling Image to (500, 408)
# Image saved as /content/gdrive/MyDrive/style_transfer_images/side_ab2_at_iteration_6.png
# Iteration 9 completed in 24s
# Starting iteration 10 of 30
# Current loss value: 1160921.4  Improvement : 7.990 %
# Rescaling Image to (500, 408)
# Image saved as /content/gdrive/MyDrive/style_transfer_images/side_ab2_at_iteration_6.png
# Iteration 10 completed in 24s
# Starting iteration 11 of 30
# Current loss value: 1074161.4  Improvement : 7.473 %
# Rescaling Image to (500, 408)
# Image saved as /content/gdrive/MyDrive/style_transfer_images/side_ab2_at_iteration_11.png
# Iteration 11 completed in 25s
# Starting iteration 12 of 30
# Current loss value: 1007597.75  Improvement : 6.197 %
# Rescaling Image to (500, 408)
# Image saved as /content/gdrive/MyDrive/style_transfer_images/side_ab2_at_iteration_11.png
# Iteration 12 completed in 25s
# Starting iteration 13 of 30
# Current loss value: 963530.75  Improvement : 4.373 %
# Rescaling Image to (500, 408)
# Image saved as /content/gdrive/MyDrive/style_transfer_images/side_ab2_at_iteration_11.png
# Iteration 13 completed in 26s
# Starting iteration 14 of 30
# Current loss value: 914835.0  Improvement : 5.054 %
# Rescaling Image to (500, 408)
# Image saved as /content/gdrive/MyDrive/style_transfer_images/side_ab2_at_iteration_11.png
# Iteration 14 completed in 25s
# Starting iteration 15 of 30
# Current loss value: 874323.56  Improvement : 4.428 %
# Rescaling Image to (500, 408)
# Image saved as /content/gdrive/MyDrive/style_transfer_images/side_ab2_at_iteration_11.png
# Iteration 15 completed in 24s
# Starting iteration 16 of 30
# Current loss value: 847041.06  Improvement : 3.120 %
# Rescaling Image to (500, 408)
# Image saved as /content/gdrive/MyDrive/style_transfer_images/side_ab2_at_iteration_16.png
# Iteration 16 completed in 25s
# Starting iteration 17 of 30
# Current loss value: 820540.75  Improvement : 3.129 %
# Rescaling Image to (500, 408)
# Image saved as /content/gdrive/MyDrive/style_transfer_images/side_ab2_at_iteration_16.png
# Iteration 17 completed in 25s
# Starting iteration 18 of 30
# Current loss value: 797592.56  Improvement : 2.797 %
# Rescaling Image to (500, 408)
# Image saved as /content/gdrive/MyDrive/style_transfer_images/side_ab2_at_iteration_16.png
# Iteration 18 completed in 25s
# Starting iteration 19 of 30
# Current loss value: 773199.1  Improvement : 3.058 %
# Rescaling Image to (500, 408)
# Image saved as /content/gdrive/MyDrive/style_transfer_images/side_ab2_at_iteration_16.png
# Iteration 19 completed in 25s
# Starting iteration 20 of 30
# Current loss value: 751975.5  Improvement : 2.745 %
# Rescaling Image to (500, 408)
# Image saved as /content/gdrive/MyDrive/style_transfer_images/side_ab2_at_iteration_16.png
# Iteration 20 completed in 24s
# Starting iteration 21 of 30
# Current loss value: 732766.56  Improvement : 2.554 %
# Rescaling Image to (500, 408)
# Image saved as /content/gdrive/MyDrive/style_transfer_images/side_ab2_at_iteration_21.png
# Iteration 21 completed in 25s
# Starting iteration 22 of 30
# Current loss value: 714007.1  Improvement : 2.560 %
# Rescaling Image to (500, 408)
# Image saved as /content/gdrive/MyDrive/style_transfer_images/side_ab2_at_iteration_21.png
# Iteration 22 completed in 24s
# Starting iteration 23 of 30
# Current loss value: 698022.25  Improvement : 2.239 %
# Rescaling Image to (500, 408)
# Image saved as /content/gdrive/MyDrive/style_transfer_images/side_ab2_at_iteration_21.png
# Iteration 23 completed in 25s
# Starting iteration 24 of 30
# Current loss value: 681154.0  Improvement : 2.417 %
# Rescaling Image to (500, 408)
# Image saved as /content/gdrive/MyDrive/style_transfer_images/side_ab2_at_iteration_21.png
# Iteration 24 completed in 25s
# Starting iteration 25 of 30
# Current loss value: 668302.8  Improvement : 1.887 %
# Rescaling Image to (500, 408)
# Image saved as /content/gdrive/MyDrive/style_transfer_images/side_ab2_at_iteration_21.png
# Iteration 25 completed in 25s
# Starting iteration 26 of 30
# Current loss value: 655110.7  Improvement : 1.974 %
# Rescaling Image to (500, 408)
# Image saved as /content/gdrive/MyDrive/style_transfer_images/side_ab2_at_iteration_26.png
# Iteration 26 completed in 25s
# Starting iteration 27 of 30
# Current loss value: 640176.9  Improvement : 2.280 %
# Rescaling Image to (500, 408)
# Image saved as /content/gdrive/MyDrive/style_transfer_images/side_ab2_at_iteration_26.png
# Iteration 27 completed in 25s
# Starting iteration 28 of 30
# Current loss value: 628069.0  Improvement : 1.891 %
# Rescaling Image to (500, 408)
# Image saved as /content/gdrive/MyDrive/style_transfer_images/side_ab2_at_iteration_26.png
# Iteration 28 completed in 24s
# Starting iteration 29 of 30
# Current loss value: 616044.1  Improvement : 1.915 %
# Rescaling Image to (500, 408)
# Image saved as /content/gdrive/MyDrive/style_transfer_images/side_ab2_at_iteration_26.png
# Iteration 29 completed in 25s
# Starting iteration 30 of 30
# Current loss value: 606360.7  Improvement : 1.572 %
# Rescaling Image to (500, 408)
# Image saved as /content/gdrive/MyDrive/style_transfer_images/side_ab2_at_iteration_26.png
# Iteration 30 completed in 25s

# %%
fig = plt.figure(figsize=(10, 10))
img = plt.imread(FINAL_IMAGE_PATH)
plt.axis('off')
plt.title('Generated image')
plt.imshow(img)

# %% [markdown]
# # (Optional) Color Transfer
#
# If you wish for color transfer between the content image and the generated image, then run the next cell, else skip to "Download Generated Image" section

# %%
COLOR_TRANSFER = 'color_transfer.py'
COLOR_FINAL_IMAGE_PATH = FINAL_IMAGE_PATH[:-4] + '_%s_color.png'

# Optional - Use Histogram matching (0 for no, 1 for yes)
HISTOGRAM_MATCH = 0

if HISTOGRAM_MATCH == 0:
  COLOR_FINAL_IMAGE_PATH = COLOR_FINAL_IMAGE_PATH % ('original')
else:
  COLOR_FINAL_IMAGE_PATH = COLOR_FINAL_IMAGE_PATH % ('histogram')
  

# !python {dir_path}/{COLOR_TRANSFER} {CONTENT_IMAGE_FN} {FINAL_IMAGE_PATH} --hist_match {HISTOGRAM_MATCH}
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /usr/local/lib/python3.6/dist-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):
# Image saved at path : generatedgen_at_iteration_15_original_color.png

# %%
fig = plt.figure(figsize=(10, 10))
img = plt.imread(COLOR_FINAL_IMAGE_PATH)
plt.axis('off')
plt.title('Color Transferred Generated image')
plt.imshow(img)

# %% [markdown]
# # Download Color Transfered Image
#
# Run the following cell to download the color transferred result

# %%
# download the color transfered image
files.download(COLOR_FINAL_IMAGE_PATH)

# %% [markdown]
# # Download Generated Image
#
# Run the following cell to download the final result

# %%
files.download(FINAL_IMAGE_PATH)
